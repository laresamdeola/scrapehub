# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)

# %%
import requests
from bs4 import BeautifulSoup
import lxml
import pandas as pd

# %%
url_total_jobs = 'https://www.totaljobs.com/jobs/in-uk?cid=SEA_GO_UK-TJ-Gen---PMAX%7C%5BA%5D_c_PMAX_PMAX_PMAX_PMAX001&gad_source=1&gclid=CjwKCAiA3ZC6BhBaEiwAeqfvymWVn6IyAfM_rZuOHGCvU2vvOSUajlsdSfWwybIZAK8BBnC2QdLCJRoChygQAvD_BwE'
response_total_jobs = requests.get(url_total_jobs)
html_content_total_jobs = response_total_jobs.text

# %%
soup = BeautifulSoup(html_content_total_jobs, 'lxml')

total_jobs_title = soup.find_all(name='div', class_='res-nehv70')
total_jobs_company_name = soup.find_all(name='span', class_='res-btchsq')
total_jobs_salary = soup.find_all(name='span', attrs={'data-at': 'job-item-salary-info'})

total_jobs_title_storage = []
total_jobs_company_name_storage = []
total_jobs_salary_storage = []

for title in total_jobs_title:
  total_jobs_title_storage.append(title.text)

for name in total_jobs_company_name:
  total_jobs_company_name_storage.append(name.text)

for salary in total_jobs_salary:
  total_jobs_salary_storage.append(salary.text)

# %%
total_jobs_title_storage
total_jobs_title_storage_2 = []

for i in range(0, len(total_jobs_title_storage), 2):
  total_jobs_title_storage_2.append(total_jobs_title_storage[i])

# %%
len(total_jobs_title_storage_2)
# Out:
# 25

# %%
total_jobs_title_storage_2
# Out:
# ['Science Management Graduate Scheme',
#  'Hospitality Manager',
#  'Learning and Development Manager',
#  'Live In Care Assistant',
#  'Work from home as an Online English as a Foreign Language Tutor - Part',
#  'Online Tutor - Part Time & No experience',
#  'Trainee Protection Adviser',
#  'Blinds & Curtains Fitter',
#  'Experienced Protection Adviser',
#  'Retail Graduate Manager',
#  'Apprentice HGV Technician',
#  'SAP Support Analyst',
#  'Business Development Manager',
#  'Flameproof Certification Engineer',
#  'Inspections Engineer',
#  'Learning and Development Partner',
#  'Lead AI Data Engineer',
#  'Lead AI Solutions Architect',
#  'GMP Production Operator',
#  'Project Coordinator',
#  'Marketing Manager Life Science',
#  'National Sales Executive',
#  'Head of Commercial Development',
#  'Business Development Manager - Advisory Services',
#  'Project Manager']

# %%
total_jobs_salary_storage
# Out:
# ['From £25,705 to £28,816 per annum depending on location + benefits',
#  'Up to £24,000 per annum plus generous benefit package including accomm',
#  'Unspecified',
#  '£910 per week (paid monthly) + a weekly food allowance of up to £49.00',
#  'From £20 to £40 per hour',
#  'From £20 to £40 per hour',
#  '£25,000 per annum plus great bonus earning opportunities',
#  'From £25,000 to £50,000 per annum',
#  '£30,000 per annum plus great bonus earning opportunities',
#  'Competitive',
#  '£11.44 per hour',
#  'From £45,000 to £55,000 per annum + Benefits',
#  'From £32,000 to £34,000 per annum DOE',
#  'Unspecified',
#  'Unspecified',
#  'Competitive',
#  'Competitive',
#  'Competitive',
#  'Unspecified',
#  '£30,000 per annum',
#  'Unspecified',
#  'Up to £38,000 per annum depending on experience',
#  '£65,000 per annum',
#  'Competitive',
#  'Unspecified']

# %%
total_jobs_company_name

total_jobs_company_name_storage_2 = []

for i in range(0, len(total_jobs_company_name_storage), 3):
  total_jobs_company_name_storage_2.append(total_jobs_company_name_storage[i])

# %%
len(total_jobs_company_name_storage_2)
# Out:
# 25

# %%
total_jobs_company_name_storage_2
# Out:
# ['Rentokil Pest Control',
#  'FIBO',
#  'Culina Group Limited',
#  'SPINAL HOMECARE SERVICES LTD',
#  'Findtutors',
#  'Findtutors',
#  'London & Country Mortgages',
#  'Hillarys Blinds',
#  'London & Country Mortgages',
#  'Asda',
#  'Culina Group',
#  'Essential Recruitment',
#  'City & Guilds',
#  'SGS United Kingdom Limited',
#  'SGS United Kingdom Limited',
#  'Culina Group',
#  'Sopra Steria Limited',
#  'Sopra Steria Limited',
#  'SGS United Kingdom Limited',
#  'Cogent Skills',
#  'SGS United Kingdom Limited',
#  'SGS United Kingdom Limited',
#  'SGS United Kingdom Limited',
#  'SGS United Kingdom Limited',
#  'SGS United Kingdom Limited']

# %%
# total_jobs_company_name

# total_jobs_company_name_2 = []

# for i in range(0, len(total_jobs_company_name)):
#   if 'UK' in total_jobs_company_name[i].text:
#     continue
#   else:
#     total_jobs_company_name_2.append(total_jobs_company_name[i].text)

# %%
len(total_jobs_title_storage_2)
# Out:
# 25

# %%
total_jobs_dataframe = pd.DataFrame(
    {'Title': total_jobs_title_storage_2,
     'Company Name': total_jobs_company_name_storage_2,
     'Salary': total_jobs_salary_storage
     })

# %%
total_jobs_dataframe
# Out:
#                                                 Title  \
# 0                  Science Management Graduate Scheme
# 1                                 Hospitality Manager
# 2                    Learning and Development Manager
# 3                              Live In Care Assistant
# 4   Work from home as an Online English as a Forei...
# 5            Online Tutor - Part Time & No experience
# 6                          Trainee Protection Adviser
# 7                            Blinds & Curtains Fitter
# 8                      Experienced Protection Adviser
# 9                             Retail Graduate Manager
# 10                          Apprentice HGV Technician
# 11                                SAP Support Analyst
# 12                       Business Development Manager
# 13                  Flameproof Certification Engineer
# 14                               Inspections Engineer
# 15                   Learning and Development Partner
# 16                              Lead AI Data Engineer
# 17                        Lead AI Solutions Architect
# 18                            GMP Production Operator
# 19                                Project Coordinator
# 20                     Marketing Manager Life Science
# 21                           National Sales Executive
# 22                     Head of Commercial Development
# 23   Business Development Manager - Advisory Services
# 24                                    Project Manager
#
#                     Company Name  \
# 0          Rentokil Pest Control
# 1                           FIBO
# 2           Culina Group Limited
# 3   SPINAL HOMECARE SERVICES LTD
# 4                     Findtutors
# 5                     Findtutors
# 6     London & Country Mortgages
# 7                Hillarys Blinds
# 8     London & Country Mortgages
# 9                           Asda
# 10                  Culina Group
# 11         Essential Recruitment
# 12                 City & Guilds
# 13    SGS United Kingdom Limited
# 14    SGS United Kingdom Limited
# 15                  Culina Group
# 16          Sopra Steria Limited
# 17          Sopra Steria Limited
# 18    SGS United Kingdom Limited
# 19                 Cogent Skills
# 20    SGS United Kingdom Limited
# 21    SGS United Kingdom Limited
# 22    SGS United Kingdom Limited
# 23    SGS United Kingdom Limited
# 24    SGS United Kingdom Limited
#
#                                                Salary
# 0   From £25,705 to £28,816 per annum depending on...
# 1   Up to £24,000 per annum plus generous benefit ...
# 2                                         Unspecified
# 3   £910 per week (paid monthly) + a weekly food a...
# 4                            From £20 to £40 per hour
# 5                            From £20 to £40 per hour
# 6   £25,000 per annum plus great bonus earning opp...
# 7                   From £25,000 to £50,000 per annum
# 8   £30,000 per annum plus great bonus earning opp...
# 9                                         Competitive
# 10                                    £11.44 per hour
# 11       From £45,000 to £55,000 per annum + Benefits
# 12              From £32,000 to £34,000 per annum DOE
# 13                                        Unspecified
# 14                                        Unspecified
# 15                                        Competitive
# 16                                        Competitive
# 17                                        Competitive
# 18                                        Unspecified
# 19                                  £30,000 per annum
# 20                                        Unspecified
# 21    Up to £38,000 per annum depending on experience
# 22                                  £65,000 per annum
# 23                                        Competitive
# 24                                        Unspecified
